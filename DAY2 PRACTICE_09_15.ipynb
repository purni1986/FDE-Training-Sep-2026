# %% [markdown]
# Homework (15 Sep 2026)

# %%
import math
math.ceil(3.5678)
# Out:
# 4

# %%
statement     = "Python is easy"
print(statement)  
print(statement[0])    # P
print(statement[-1])
# Out:
# Python is easy
# P
# y

# %%
statement= "Rishi Kumar"
print(statement.upper())   # RISHI KUMAR
print(statement.lower())   # rishi kumar
print(statement.title())   # Rishi Kumar
print(statement.swapcase())# rISHI kUMAR
# Out:
# RISHI KUMAR
# rishi kumar
# Rishi Kumar
# rISHI kUMAR

# %%
name = "India"
print(name.isalpha())   # True
print(name.isdigit())   # False
print(name.isalnum())   # True
print(name.isspace())
# Out:
# True
# False
# True
# False

# %%
name = "India "
print(name.isspace())
# Out:
# False

# %%
name = " "
print(name.isspace())
# Out:
# True

# %%
name="name"

for n in name:
    print(name.count(n))
# Out:
# 1
# 1
# 1
# 1

# %%
name ="name"
total_char=0

for char in name:
    total_char=total_char+1
print(total_char)
# Out:
# 4

# %%
some=None
print(type(some))
# Out:
# <class 'NoneType'>

# %%
s = "Python_Sampath"
print("Sampath" not in s)     # True
print("abc"  in s) # True
# Out:
# False
# False

# %%
str = "Hello World"
print(str.startswith("Hello"))  # True
print(str.endswith("World"))
# Out:
# True
# True

# %%
fruit1 = "apple"
fruit2 = "banana"
print(fruit1 == fruit2)   # False
print(fruit1 < fruit2)
# Out:
# False
# True

# %%
#Comparing strings without using Comparison operator

fruit1 = "apple"
fruit2 = "banana"

# Using the internal equality method
print(fruit1.__eq__(fruit2))  # False

# Using dictionary lookups (Returns True if they are identical keys)
print(fruit1 in {fruit2: True})  # False
# Out:
# False
# False

# %%
s = "banana"
print(s.count("a"))
# Out:
# 3

# %% [markdown]
# #Any Datatype
#
# from typing import Any
#
# # We tell Python: "This variable can hold absolutely anything"
# something: Any = "Hello"
#
# # Later, we can change it to a completely different data type
# something = 42
#
# # Later, we can change it to a list
# something = [1, 2, 3]

# %% [markdown]
# name = "Rakesh"
# age = 30
# print("My name is {} and age is {}".format( age,name))
# print(f"My name is {name} and age is {age}")
#
# # code for using int or float,decimal in format
# height = 5.9
# print("My name is {} and age is {} and height is {}".format(name, age, height))
# print(f"My name is {name}, age is {age}, and height is {height}")
# print("My name is {0}, age is {1}, and height is {2}".format(name, age, height))
# print("My name is {n}, age is {a}, and height is {h}".format(n=name, a=age, h=height))
# print(f"My name is {name}, age is {age}, and height is {height:.1f}")  # formatted to 1 decimal place
# #print("My name is {}, age is {}, and height is {:.1f}".format(name, age, height))  # formatted to 1 decimal place
# print("My name is {0}, age is {1}, and height is {2:.1f}".format(name, age, height))  # formatted to 1 decimal place
# print("My name is {n}, age is {a}, and height is {h:.1f}".format(n=name, a=age, h=height))  # formatted to 1 decimal place
#
#
#
# # #number formatting for signed numbers,decimals,floats etc
# # num = 1234.56789
# # print("Formatted number (default): {}".format(num))
# # print("Formatted number (2 decimal places): {:.2f}".format(num))
# # print("Formatted number (signed): {:+.2f}".format(num))
# # # print("Formatted number (with thousands separator): {:,.2f}".format(num))

# %%
name = "Rakesh"
age = 30
print("My name is {} and age is {}".format( name,age))
print(f"My name is {name} and age is {age}")
# Out:
# My name is Rakesh and age is 30
# My name is Rakesh and age is 30

# %%
height = 5.9
print("My name is {} and age is {} and height is {}".format(name, age, height))
print(f"My name is {name}, age is {age}, and height is {height}")
print("My name is {0}, age is {1}, and height is {2}".format(name, age, height))
print("My name is {n}, age is {a}, and height is {h}".format(n=name, a=age, h=height))
print(f"My name is {name}, age is {age}, and height is {height:.1f}")  # formatted to 1 decimal place
#print("My name is {}, age is {}, and height is {:.1f}".format(name, age, height))  # formatted to 1 decimal place
print("My name is {0}, age is {1}, and height is {2:.1f}".format(name, age, height))  # formatted to 1 decimal place
print("My name is {n}, age is {a}, and height is {h:.1f}".format(n=name, a=age, h=height))  # formatted to 1 decimal place
# Out:
# My name is Rakesh and age is 30 and height is 5.9
# My name is Rakesh, age is 30, and height is 5.9
# My name is Rakesh, age is 30, and height is 5.9
# My name is Rakesh, age is 30, and height is 5.9
# My name is Rakesh, age is 30, and height is 5.9
# My name is Rakesh, age is 30, and height is 5.9
# My name is Rakesh, age is 30, and height is 5.9

# %%
# #number formatting for signed numbers,decimals,floats etc
num = 1234.56789
print("Formatted number (default): {}".format(num))
print("Formatted number (2 decimal places): {:.2f}".format(num))
print("Formatted number (signed): {:+.2f}".format(num))
print("Formatted number (with thousands separator): {:,.2f}".format(num))
# Out:
# Formatted number (default): 1234.56789
# Formatted number (2 decimal places): 1234.57
# Formatted number (signed): +1234.57
# Formatted number (with thousands separator): 1,234.57

# %%
num= 3.1456784534766887899

print ("The formatted number till 16 decimal places:{:.16f}".format(num))
# Out:
# The formatted number till 16 decimal places:3.1456784534766888

# %%
# Reverse a string
s = "Python"
print(s[::-1])  # nohtyP

# Palindrome check  
word = "madam"
print(word == word[::-1])  # True

# Count vowels
s = "Hello World"
vowels = "aeiouAEIOU"
count=0
for char in s:
    if char in vowels:
       count=count+1
print(count)
# Out:
# nohtyP
# True
# 3
